# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/no_throw_2.csv", sep=",")
df
# Out:
#         X-Axis    Y-Axis    Z-Axis
# 0    -0.629624  0.056062 -0.970312
# 1    -0.616687  0.051750 -0.965999
# 2    -0.625312  0.047438 -0.957374
# 3    -0.625312  0.051750 -0.961687
# 4    -0.629624  0.060375 -0.957374
# ...        ...       ...       ...
# 1145 -0.633937  0.030187 -0.948749
# 1146 -0.642562  0.021562 -0.974624
# 1147 -0.646874  0.034500 -0.965999
# 1148 -0.664124  0.056062 -0.961687
# 1149 -0.646874  0.021562 -0.970312
#
# [1150 rows x 3 columns]

# %%
df.describe()
# Out:
#             X-Axis       Y-Axis       Z-Axis
# count  1150.000000  1150.000000  1150.000000
# mean     -0.636127     0.035704    -0.969445
# std       0.012366     0.015936     0.015025
# min      -0.668437    -0.004312    -1.017750
# 25%      -0.642562     0.025875    -0.978937
# 50%      -0.638249     0.034500    -0.970312
# 75%      -0.629624     0.043125    -0.957374
# max      -0.595124     0.094875    -0.922874

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, tight_layout=True, figsize=(15, 8))
axs[0].plot(df["X-Axis"])
axs[0].set_title("X-Axis")
axs[1].plot(df["Y-Axis"])
axs[1].set_title("Y-Axis")
axs[2].plot(df["Z-Axis"])
axs[2].set_title("Z-Axis")
# Out:
# Text(0.5, 1.0, 'Z-Axis')
