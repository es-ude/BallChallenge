# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# Parameters
num_rows = 1000
board_size = 2  # meters
distance_to_board = 1  # meter (distance from throw point to the side of the board)

def simulate_throw(vel_x, vel_y, vel_z, initial_height=0):
    """
    Simulates the throw of a ball given x, y, z accelerations.
    """
    g = 9.81  # gravitational acceleration (m/s^2)

    # Initial conditions
    initial_position_x = 0
    initial_position_y = 0
    initial_position_z = 1
    #Calculate time since thrown until it hits the floor
    t = (vel_y+ np.sqrt(vel_z**2 + 2 * g * initial_position_z))/g
    # Compute final positions after time t
    position_x = initial_position_x + vel_x * t
    position_y = initial_position_y + vel_y * t

    # Adjust the landing coordinates to the board's coordinate system
    final_position_x= position_x +distance_to_board
    final_position_y= position_y -board_size/2
    return final_position_x, final_position_y



# Create an empty DataFrame
columns = ['vel_x', 'vel_y', 'vel_z', 'landing_x,y']
data = []

while len(data) < num_rows:
    # Generate random accelerations
    vel_x = np.random.uniform(-10, 10)
    vel_y = np.random.uniform(0, 20)
    vel_z = np.random.uniform(0, 20)

    # Simulate the throw
    landing_x, landing_y= simulate_throw(vel_x, vel_y, vel_z)

    # Check if the ball lands on the board
    if 0 <= landing_x <= board_size and 0 <= landing_y <= board_size:  data.append([vel_x, vel_y, vel_z, (landing_x, landing_y)])

# Create DataFrame
df = pd.DataFrame(data, columns=columns)
df
# Out:
#         vel_x     vel_y      vel_z                                landing_x,y
# 0    0.137626  1.980871   1.940815   (1.0956347461812237, 0.3764849812862039)
# 1    0.481326  1.737437   2.743068   (1.340876413552912, 0.23045742892671273)
# 2    0.409684  1.191854  19.171434   (1.8715006563722731, 1.5353736600091308)
# 3    0.517014  2.058578   8.893906    (1.632141064613157, 1.5169730528929501)
# 4    0.230875  3.354702   2.867905     (1.2031399762460329, 1.95170177999284)
# ..        ...       ...        ...                                        ...
# 995 -0.018328  1.973436   6.209425    (0.9820630355427987, 0.931355694107461)
# 996 -0.259129  2.240894   0.383422     (0.823366562363778, 0.527486405663891)
# 997 -0.104934  0.855060  12.745218  (0.8465244296980183, 0.25060487713238366)
# 998  0.389807  2.404223   3.435470   (1.3182746712740216, 0.9630314992926612)
# 999 -0.576028  2.183029  10.220880   (0.2177272552280628, 1.9646556751829607)
#
# [1000 rows x 4 columns]
